# %%
import json
import pathlib
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

from modelling import phased_model_training, write_predictions

# %%
# Load configuration settings 
with open('config.json', 'r') as fp:
    config = json.load(fp)

# %%
#with open('config.json', 'w') as fp:
#    json.dump(config, fp)

# %%
phased_model_training(config)

# %%
write_predictions(config, model_file_name='20221130135512_phase_2_model.pt')

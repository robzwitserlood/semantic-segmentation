# %%
# %load_ext autoreload
# %autoreload 1

import json
import pathlib
import cv2
import warnings
import matplotlib

# %aimport download_data

warnings.filterwarnings('ignore')
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 16})

# %%
# Load configuration settings 
with open('satellite_imagery_config.json', 'r') as fp:
    config = json.load(fp)

# %%
#!python download_data.py
